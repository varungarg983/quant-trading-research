# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import json

# %%
with open('/home/varun-garg/Downloads/Quant Trading/Sakshi Tiktok Analytics/TikTok_Data_1778568183/user_data_tiktok.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data["Post"]["Posts"]["VideoList"])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 158 non-null    str
#  1   Link                 158 non-null    str
#  2   Likes                158 non-null    str
#  3   WhoCanView           158 non-null    str
#  4   AllowComments        158 non-null    str
#  5   AllowStitches        158 non-null    str
#  6   AllowDuets           158 non-null    str
#  7   AllowStickers        158 non-null    str
#  8   AllowSharingToStory  158 non-null    str
#  9   ContentDisclosure    158 non-null    str
#  10  AIGeneratedContent   158 non-null    str
#  11  Sound                158 non-null    str
#  12  Location             158 non-null    str
#  13  Title                158 non-null    str
#  14  AddYoursText         158 non-null    str
#  15  AlternateText        158 non-null    str
# ...
